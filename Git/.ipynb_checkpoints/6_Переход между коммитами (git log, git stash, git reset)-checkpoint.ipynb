# %% [markdown]
# # Git log -
#
#
# ### это команда, позволяющая
#     - просмотреть историю коммитов в репозитории
#     - производить поиск/фильтрацию коммитов по тексту сообщений,
#     измененным файлам, датам, авторам, веткам и прочим параметрам
#
#
# ***
#
# ### Базовый вывод команды git log для одного коммита:
#
# ![image.png](attachment:image.png)
#
# По умолчанию, история выводится в обратном хронологическом порядке.
# Отображается хэш коммита, связанные ветки, данные от авторе и дате коммита,
# а также сообщение и метка, смержен коммит или нет.
#
#
# ***
# ### Пример коммита в git log, которыя является мержем пулл-реквеста:
#
# ![image-2.png](attachment:image-2.png)
#
#
# ***
# У git log достаточно много параметров для отображения и поиска по коммитам, перечислять их все в рамках урока не имеет смысла. Подробнее ознакомиться с параметрами можно в [документации](https://git-scm.com/docs/git-log)
#
#
#
# ### Наиболее распространенные параметры:
#
# > **Флаг -p** (подробная информацию обо всех изменениях, внесенных коммитом)
#
# ![image-3.png](attachment:image-3.png)
#
#
# > **Параметр --pretty. Доступные пресеты: oneline, short, full и fuller**
# (управляет выводом деталей в git log при помощи готовых пресетов)
#
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-7.png](attachment:image-7.png)
#
#
#
# > **Параметр format** (git log позволяет полностью настроить формат вывода)
#
#
# ![image-5.png](attachment:image-5.png)
#
# `Где %h - хэш коммита, %an - имя автора, %ar - относительная дата, %s - сообщение коммита.`
#
#
#
#
# > **git checkout** подходит не только для переключения между ветками, но и между коммитами и тегами.
#
#
#
# ### Использование
#
#
# `git checkout [options] [<branch>]/<commit>/<tag>`
# `git checkout [options] <file_name_to_restore>`
#
#
#
# ### Ссылки
#
# Подробнее: [git checkout](https://git-scm.com/docs/git-checkout), [git log](https://git-scm.com/book/ru/v1/%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D1%8B-Git-%D0%9F%D1%80%D0%BE%D1%81%D0%BC%D0%BE%D1%82%D1%80-%D0%B8%D1%81%D1%82%D0%BE%D1%80%D0%B8%D0%B8-%D0%BA%D0%BE%D0%BC%D0%BC%D0%B8%D1%82%D0%BE%D0%B2)

# %% [markdown]
# ### Задача 6.1 (найти хеш по сообщению и скопировать в файл)
#
# У вас есть локальный репозиторий  в `/home/box/REPO`.
# Найдите  в истории коммит с сообщением `"Git rules!"`
# и напишите его хэш (полностью) в файл `/home/box/answer`.
#
# Подробнее: [git log](https://git-scm.com/docs/git-log)
#
# <details><summary><b>Ответ</b></summary>
#
# ```
# git log --grep='Git rules!' --format='%H' > /home/box/answer
# ```
#
# </details>

# %% [markdown]
# ### Задача 6.1.2 (найти по сообщению коммит и переключиться на него)
#
#
# Аналогично предыдущему заданию, у вас есть локальный репозиторий  в `/home/box/REPO`
# **Требуется найти коммит, сообщение которого содержит `"Git rules!"`,  и переключиться к этому коммиту.**
#
# Подробнее:
#
# [git checkout](https://git-scm.com/docs/git-checkout), [git log ru](https://git-scm.com/book/ru/v2/%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D1%8B-Git-%D0%9F%D1%80%D0%BE%D1%81%D0%BC%D0%BE%D1%82%D1%80-%D0%B8%D1%81%D1%82%D0%BE%D1%80%D0%B8%D0%B8-%D0%BA%D0%BE%D0%BC%D0%BC%D0%B8%D1%82%D0%BE%D0%B2)
#
# ***
#
#
# <details><summary><b>Ответ</b></summary>
#
# ```
# git log --grep "Git rules!"    выведет коммит и хэш
# git checkout <хэш коммита>
#
#     или
#
# git checkout $(git log --grep='Git rules!' --pretty=format:%H)
#
#     или
#
# git log --grep="Git rules!" --pretty=format:"%H" | git checkout
#
# ```
#
# </details>

# %% [markdown]
# # Git stash -
#
#
# ### это команда для хранения изменений, которые по каким-либо причинам не нужно включать в коммит.
#
#
# > **Например, в ситуации, когда нужно быстро переключиться между ветками, но работа ещё не завершена**.
#
# > **stash сохраняет текущее состояние репозитория, то есть измененные отслеживаемые файлы, без создания коммита. Неотслеживаемые файлы в stash не включаются**.
#
# Допустим, имеется ветка master с некоторыми изменениями:
#
# ![image.png](attachment:image.png)
#
#
# В данной ситуации невозможно переключиться на другую ветку без сохранения или отклонения изменений.
#
#
# ***
#
# ### Для сохранения данных
# можно создать коммит и, впоследствии, сделать squash, но **гораздо проще временно сохранить изменения в отдельном хранилище - stash**:
#
# ![image-2.png](attachment:image-2.png)
#
#
# Для просмотра записей в stash можно воспользоваться параметром list:
#
# ![image-3.png](attachment:image-3.png)
#
#
# ***
#
# ### Для возврата сохраненных изменений
# **можно воспользоваться командами git stash pop или git stash apply**
# Если записей в  stash несколько, можно указать индекс записи, которую необходимо применить
# (указана в фигурных скобках). Если индекс не указан, применяются изменения последней добавленной записи:
#
# ![image-4.png](attachment:image-4.png)
#
# ***
#
# ### Для удаления записей из stash
# **используется команда _git stash drop_**. Принцип работы аналогичен pop: можно указать индекс удаляемой записи, либо применить без индекса и удалить последнюю добавленную запись в  stash:
#
# ![image-6.png](attachment:image-6.png)
#
#
#
# **Дополнительно:** [git stash](https://git-scm.com/book/ru/v1/%D0%98%D0%BD%D1%81%D1%82%D1%80%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D1%8B-Git-%D0%9F%D1%80%D1%8F%D1%82%D0%B0%D0%BD%D1%8C%D0%B5)

# %% [markdown]
# ### Задача 6.2.2 (извлечение данных из stash)
#
#
# В директории `/home/box/REPO` располагается локальный репозиторий.
# **Необходимо при помощи команды `git stash` извлечь сохраненные изменения в stash**.
#
# _Ничего удалять/создавать/коммитить не нужно._
#
# ***
#
#
# <details><summary><b>Ответ</b></summary>
#
# ```
#     cd REPO
#     git stash list
#     git stash pop
# ```
#
# </details>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Задача 6.2.3 (удаление из stash)
#
# В директории `/home/box/REPO` располагается локальный репозиторий.
# **Необходимо при помощи команды `git stash` удалить все сохраненные изменения из stash**.
#
# _Ничего создавать/коммитить не нужно._
#
# ***
#
#
# <details><summary><b>Ответ</b></summary>
#
# ```
#     cd REPO
#     git stash list
#     git stash drop
# ```
#
# </details>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # git reset
#
# Результат команды git reset сильно зависит от того, какой флаг (soft, mixed или hard) указан при выполнении. По умолчанию - mixed.
#
# Для детального рассмотрения работы команды reset необходимо вспомнить, какие структуры существуют при работе с git:
#
# - **рабочий каталог** - это, по сути, каталог, в котором ведется работа;
# - **индекс** - это область подготовленных изменений, то есть те изменения, которые будут включены в коммит;
# - **HEAD** - это указатель на состояние текущей ветки, то есть на последний коммит в текущей ветке.
#
#
# Допустим, имеется следующая история коммитов:
#
# ![image.png](attachment:image.png)
#
#
#
# Рассмотрим, что именно происходит при выполнении команды **git reset**:
#
# ### git reset --soft HEAD~
#
# Во-первых, перемещается HEAD. То есть, при выполнении
#
# > `git reset --soft HEAD~`
#
#
# репозиторий меняется следующим образом:
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# При выполнении **git status**:
#
# ![image-3.png](attachment:image-3.png)
#
#
# При выполнении git log будут отображены только коммиты C0 и C1.
#
# Если открыть содержимое файла README.md,  можно увидеть, что оно не изменилось относительно коммита C2. Таким образом, reset soft перемещает HEAD на предыдущий коммит, но ни индекс, ни рабочий каталог при этом не изменяются.
#
#
#
# ### git reset --mixed HEAD~
# reset mixed, по сути, включает в себя применение soft, а также изменение индекса.
#
# То есть, при выполнении git status после **git reset --mixed HEAD~** :
#
# ![image-4.png](attachment:image-4.png)
#
#
# Видно, что изменения README.md не включены в коммит. При этом, содержимое файла README.md не изменится.
#
#
#
# ### git reset --hard HEAD~
# reset hard включает в себя mixed, а также приведение рабочего каталога к тому же виду, что и индекс:
#
# ![image-5.png](attachment:image-5.png)
#
#
# При этом, содержимое файла README.md вернется к той версии, на которую теперь указывает HEAD,  то есть к состоянию в коммите C1.

# %% [markdown]
# ***
#
# ### Задачи git reset
#
#    1) В директории **/home/box/REPO** располагается локальный репозиторий.
#    Необходимо при помощи команды git reset **откатиться к предыдущему коммиту
#    с восстановлением индекса, но без изменений рабочего каталога**
#    ///
#
#
# <details><summary>-- Ответ --</summary>
#
# ```
#     cd REPO
#     git reset --mixed HEAD~
#
# ```
#
# </details>
#
# ***
# 2) ...откатиться к предыдущему коммиту **без изменений в индексе или рабочем каталоге**
#
#
# <details><summary>-- Ответ --</summary>
#
# ```
#     cd REPO
#     git reset --soft HEAD~
#
# ```
#
# </details>
#
#
# ***
# 3) ...откатиться к предыдущему коммиту **с восстановлением как индекса, так и рабочего каталога**
#
#
# <details><summary>-- Ответ --</summary>
#
# ```
#     cd REPO
#     git reset --hard HEAD~
#
# ```
#
# </details>
