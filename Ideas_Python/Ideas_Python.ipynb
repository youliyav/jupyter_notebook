# %% [markdown]
# ### 1. Проект загрузки фотографий из Instagram
#
# _Идея проекта Python - проект загрузчика фотографий из Instagram используется для загрузки всех изображений из Instagram ваших друзей_
#
# Он будет использовать ваши учетные данные для доступа к вашей учетной записи, а затем будет искать ваших друзей, чтобы загрузить их фотографии.
#
#
# ### 2. Система управления библиотекой
#
# _Проект Python - цель проекта системы управления библиотеками - разработать проект библиотеки в реальном времени с помощью Tkinter._
#
# Этот проект предоставляет такие функции, как добавление книги, выпуск журнала, возврат книги, просмотр книги, удаление книги и т. Д.
#
# **Исходный код - [проект Python системы управления библиотеками][1]**
#
#
# ### 3. Тест скорости набора текста в Python
# _C помощью которого вы можете проверить свою скорость набора текста._
#
# Вы должны создать графический пользовательский интерфейс с помощью библиотеки GUI, такой как Tkinter, тогда пользователь должен ввести случайное предложение, и когда пользователь завершит набор, мы отобразим скорость набора, точность и количество слов в минуту.
#
# **Исходный код - [проект Python по тесту скорости набора текста][2]**
#
#
# ### 4. Расширение сравнения цен
# _Это потрясающий проект, в котором вы можете сравнивать цены на продукт из нескольких веб-источников_
#
# Как и на веб-сайте Trivago, мы можем сравнивать цены на отели, аналогично мы можем сравнивать цены на продукты на таких веб-сайтах, как Amazon, Snapdeal, Flipkart и т.д. и отображать лучшие предложения.
#
#
# ### 5. Конвертирование текста в голос
# **[Урок по конвертации][3]**
#
#
# [1]:https://data-flair.training/blogs/library-management-system-python-project/
# [2]:https://techvidvan.com/tutorials/project-in-python-typing-speed-test/
# [3]:https://data-flair.training/blogs/python-text-to-speech/
